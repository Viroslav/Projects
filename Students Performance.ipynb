# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv("C:Desktop/Data_Science/DS/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df = df.rename(columns={'math score':"math_score",
                  'reading score':"reading_score",
                  'writing score':"writing_score",})

# %%
df['total_score'] = df.math_score + df.reading_score + df.writing_score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score  \
# ...

# %%
df.query('lunch == "standard"').mean()
# Out:
# math_score        70.034109
# reading_score     71.654264
# writing_score     70.823256
# total_score      212.511628
# dtype: float64

# %% [markdown]
# df.query('lunch == "standard"').mean()

# %%
df.query('lunch == "free/reduced"').mean()
# Out:
# math_score        58.921127
# reading_score     64.653521
# writing_score     63.022535
# total_score      186.597183
# dtype: float64

# %%
df.query('lunch == "free/reduced"').total_score.plot()
df.query('lunch == "standard"').total_score.plot()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  total_score
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000
# std      15.16308      14.600192      15.195657    42.771978
# min       0.00000      17.000000      10.000000    27.000000
# 25%      57.00000      59.000000      57.750000   175.000000
# 50%      66.00000      70.000000      69.000000   205.000000
# 75%      77.00000      79.000000      79.000000   233.000000
# max     100.00000     100.000000     100.000000   300.000000
